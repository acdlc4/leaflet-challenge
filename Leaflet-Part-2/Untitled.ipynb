# %%
# Dependencies
import json
from pathlib import Path
from pprint import pprint

# Load JSON
filepath = Path("resources/tectonicplates-master/GeoJSON/PB2002_plates.json")
with open(filepath) as jsonfile:
    plates = json.load(jsonfile)

geometry = plates['features'][0]['geometry']['coordinates'][0]

# %%
pprint(geometry)
# Out:
# [[-0.4379, -54.8518],
#  [-0.914655, -54.4535],
#  [-1.3822, -54.0533],
#  [-2.37231, -54.3274],
#  [-2.91952, -53.5469],
#  [-3.44688, -52.764],
#  [-3.95559, -51.9788],
#  [-4.23767, -52.0486],
#  [-4.47762, -51.5912],
#  [-4.71279, -51.1333],
#  [-4.94334, -50.6749],
#  [-5.16942, -50.2161],
#  [-6.15983, -50.4171],
#  [-7.15851, -50.6096],
#  [-7.43284, -50.0013],
#  [-7.63767, -50.0587],
#  [-7.96086, -49.2702],
#  [-8.02211, -49.2826],
#  [-8.13908, -48.961],
#  [-8.92248, -49.0912],
#  [-9.70992, -49.216],
#  [-9.90926, -48.6939],
#  [-10.1045, -48.1715],
#  [-10.2958, -47.6487],
#  [-10.4834, -47.1256],
#  [-11.1892, -47.2452],
#  [-11.8982, -47.3605],
#  [-12.6102, -47.4714],
#  [-13.3251, -47.5778],
#  [-13.5715, -46.6878],
#  [-13.81, -45.7972],
#  [-14.7155, -45.8985],
#  [-14.894, -45.3714],
#  [-15.5939, -45.4756],
#  [-15.7603, -45.0279],
#  [-15.9242, -44.58],
#  [-16.0856, -44.1319],
#  [-16.2445, -43.6835],
#  [-16.3296, -43.387],
#  [-16.4299, -42.8677],
# ...
